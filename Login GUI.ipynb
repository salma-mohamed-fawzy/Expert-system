# %%
from tkinter import *

root = Tk()

root.geometry("600x500")

root.title("Regtistration Form")

####################################

#label
lb1 = Label(root,text="Regtistration Form",height="5",font="200")

# text
lb2 = Label(root,text="Full Name",height="1",font="35",fg="black")#entry
E1 = Entry(root,font="35",fg="black")
# text
lb3 = Label(root,text="Email",height="4",font="35",fg="black")#entry
E2 = Entry(root,font="35",fg="black")

# text
lb4 = Label(root,text="Gender",height="2",font="35",fg="black")#entry
rdbtn1=Radiobutton(root,text="male",font="35",value=1)
rdbtn2=Radiobutton(root,text="female",font="35",value=2)

lb5 = Label(root,text="Country",height="2",font="35",fg="black")#entry
#Listbox
List1 = Listbox(root,height="1")
List1.insert(1, 'Egypt')
List1.insert(2, 'Deutshland')
List1.insert(3, 'England')
List1.insert(4, 'Any other')

lb6 = Label(root,text="Programming",height="2",font="10",fg="black")#entry
chk1 = Checkbutton(root, text = "java", font="20")
chk2 = Checkbutton(root, text = "python", font="20")

btn=Button(root,text="Submit",width="7",height="2",font="30",bg="red",fg="white")
###################################
lb1.place(x = 1, y = 1) 

E1.place(x = 110, y = 80)
lb2.place(x = 1, y = 72)

lb3.place(x = 1, y = 90)
E2.place(x = 110, y = 120)

lb4.place(x = 1, y = 150)
rdbtn1.place(x = 100, y = 160)
rdbtn2.place(x =160 , y = 160)

lb5.place(x = 1, y = 190)
List1.place(x = 105, y = 200)

lb6.place(x = 1, y = 230)
chk1.place(x = 110, y = 240)
chk2.place(x = 180, y = 240)

btn.place(x = 1, y = 290)

root.mainloop()

# %%
# Import module
from tkinter import *

# Create object
root = Tk()

# Adjust size
root.geometry("400x400")

# Add image file
bg = PhotoImage(file= "bg.png")
# Show image using label
label1 = Label( root, image = bg)
label1.place(x = 0,y = 0)

# Execute tkinter
root.mainloop()
