# %% [markdown]
# # Pharmaceutical expert systems in CLI

# %%
from experta import *
class pharmacy(KnowledgeEngine):
	@DefFacts()
	def _initial_action(self):
		print("")
		print("Welcome!")
		print("We are so happy to help you find the appropriate medicine for your case ")
		print("We provide arabic translation for symptoms&chronic diseases and provide medicine in arabic for easy use ... ")
		print("Warn! Use this system only if you are 12 years old or more ")
		print("Now, answer the following questions by 'yes' or 'no' ")
		print("\n")

		yield Fact(action="pharmacy")

	@Rule(Fact(action='pharmacy'), NOT(Fact(runnynose=W())))
	def fun0(self):
		self.declare(Fact(runnynose=input("Runny Nose 'رشح': ")))

	@Rule(Fact(action='pharmacy'), NOT(Fact(asthma=W())))
	def fun1(self):
		self.declare(Fact(asthma=input("Asthma 'ربو': ")))

	@Rule(Fact(action='pharmacy'), NOT(Fact(Diabetes=W())))
	def fun2(self):
		self.declare(Fact(Diabetes=input("Diabetes 'مرض السكري': ")))
        
	@Rule(Fact(action='pharmacy'), NOT(Fact(pressure=W())))
	def fun3(self):
		self.declare(Fact(pressure=input("Pressure 'ضغط': ")))

	@Rule(Fact(action='pharmacy'), NOT(Fact(headache=W())))
	def fun4(self):
		self.declare(Fact(headache=input("Headache 'صداع': ")))

	@Rule(Fact(action='pharmacy'), NOT(Fact(sore_throat=W())))
	def fun5(self):
		self.declare(Fact(sore_throat=input("sore throat 'التهاب في الحلق': ")))

##################################################### medicine according to disease ##############################################

# رشح بدون امراض مزمنة
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="no"),Fact(pressure="no"),Fact(headache="no"),Fact(sore_throat="no"))
	def med0(self):
		self.declare(Fact(medicine="بانادول اصفر"))
# رشح مع امراض مزمنة(ربو)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="no"),Fact(pressure="no"),Fact(headache="no"),Fact(sore_throat="no"))
	def med1(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي"))
 # رشح مع امراض مزمنة(ربو,سكري)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="yes"),Fact(pressure="no"),Fact(headache="no"),Fact(sore_throat="no"))
	def med2(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي"))
# رشح مع امراض مزمنة(ربو,سكري,ضغط)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="yes"),Fact(pressure="yes"),Fact(headache="no"),Fact(sore_throat="no"))
	def med3(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين"))
# رشح مع امراض مزمنة(ربو,ضغط)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="no"),Fact(pressure="yes"),Fact(headache="no"),Fact(sore_throat="no"))
	def med4(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين"))
# رشح مع امراض مزمنة(ضغط)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="no"),Fact(pressure="yes"),Fact(headache="no"),Fact(sore_throat="no"))
	def med5(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين"))
# رشح مع امراض مزمنة(ضغط,سكري)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="no"),Fact(asthma="no"),Fact(Diabetes="no"),Fact(pressure="no"),Fact(headache="no"),Fact(sore_throat="no"))
	def med6(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي"))
# رشح مع امراض مزمنة(سكري)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="yes"),Fact(pressure="no"),Fact(headache="no"),Fact(sore_throat="no"))
	def med7(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي"))
#رشح + صداع 
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="no"),Fact(pressure="no"),Fact(headache="yes"),Fact(sore_throat="no"))
	def med8(self):
		self.declare(Fact(medicine="بانادول أصفر"))
# رشح + صداع مع امراض مزمنة(ربو)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="no"),Fact(pressure="no"),Fact(headache="yes"),Fact(sore_throat="no"))
	def med9(self):
		self.declare(Fact(medicine="بانادول أصفر"))
# رشح+ صداع مع امراض مزمنة(ربو,سكري)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="yes"),Fact(pressure="no"),Fact(headache="yes"),Fact(sore_throat="no"))
	def med10(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي"))
 # رشح + صداع مع امراض مزمنة(ربو,سكري,ضغط)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="yes"),Fact(pressure="yes"),Fact(headache="yes"),Fact(sore_throat="no"))
	def med11(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين"))
  # رشح + صداع مع امراض مزمنة(ربو,ضغط)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="no"),Fact(pressure="yes"),Fact(headache="yes"),Fact(sore_throat="no"))
	def med12(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين"))
  # رشح + صداع مع امراض مزمنة(ضغط)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="no"),Fact(pressure="yes"),Fact(headache="yes"),Fact(sore_throat="no"))
	def med13(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين" ))
 # رشح + صداع مع امراض مزمنة(ضغط,سكري)    
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="yes"),Fact(pressure="yes"),Fact(headache="yes"),Fact(sore_throat="no"))
	def med14(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي"))
   # رشح + صداع مع امراض مزمنة(سكري)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="yes"),Fact(pressure="no"),Fact(headache="yes"),Fact(sore_throat="no"))
	def med15(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي"))
  # رشح + صداع + التهاب حلق
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="no"),Fact(pressure="no"),Fact(headache="yes"),Fact(sore_throat="yes"))
	def med16(self):
		self.declare(Fact(medicine="بانادول اصفر + أبيبول"))
 # رشح + صداع + التهاب حلق مع امراض مزمنة(ربو)       
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="no"),Fact(pressure="no"),Fact(headache="yes"),Fact(sore_throat="yes"))
	def med17(self):
		self.declare(Fact(medicine="بنادول أصفر+أبيبول"))
 # رشح+ صداع + التهاب حلق مع امراض مزمنة(ربو,سكري)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="yes"),Fact(pressure="no"),Fact(headache="yes"),Fact(sore_throat="yes"))
	def med18(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي+أبيبول"))
 # رشح + صداع + التهاب حلق مع امراض مزمنة(ربو,سكري,ضغط)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="yes"),Fact(pressure="yes"),Fact(headache="yes"),Fact(sore_throat="yes"))
	def med19(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين+أبيبول"))
# رشح + صداع + التهاب حلق مع امراض مزمنة(ربو,ضغط)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="no"),Fact(pressure="yes"),Fact(headache="yes"),Fact(sore_throat="yes"))
	def med20(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين+أبيبول"))
# رشح + صداع + التهاب حلق مع امراض مزمنة(ضغط)          
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="no"),Fact(pressure="yes"),Fact(headache="yes"),Fact(sore_throat="yes"))
	def med21(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين+أبيبول"))
# رشح + صداع + التهاب حلق مع امراض مزمنة(ضغط,سكري)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="yes"),Fact(pressure="yes"),Fact(headache="yes"),Fact(sore_throat="yes"))
	def med22(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي+أبيبول"))
 # رشح + صداع + التهاب حلق مع امراض مزمنة(سكري)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="yes"),Fact(pressure="no"),Fact(headache="yes"),Fact(sore_throat="yes"))
	def med23(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي+أبيبول"))
# رشح + التهاب حلق
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="no"),Fact(pressure="no"),Fact(headache="no"),Fact(sore_throat="yes"))
	def med24(self):
		self.declare(Fact(medicine="كلاريناز + أبيبول"))
# رشح + التهاب حلق مع امراض مزمنة(ربو)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="no"),Fact(pressure="no"),Fact(headache="no"),Fact(sore_throat="yes"))
	def med25(self):
		self.declare(Fact(medicine="كلاريناز + أبيبول"))
  # رشح+ التهاب حلق مع امراض مزمنة(ربو,سكري)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="yes"),Fact(pressure="no"),Fact(headache="no"),Fact(sore_throat="yes"))
	def med26(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي + أبيبول"))
# رشح + التهاب حلق مع امراض مزمنة(ربو,سكري,ضغط)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="yes"),Fact(pressure="yes"),Fact(headache="no"),Fact(sore_throat="yes"))
	def med27(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين + أبيبول"))
  # رشح + التهاب حلق مع امراض مزمنة(ربو,ضغط)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="no"),Fact(pressure="yes"),Fact(headache="no"),Fact(sore_throat="yes"))
	def med28(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين + أبيبول "))
# رشح + التهاب حلق مع امراض مزمنة(ضغط)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="no"),Fact(pressure="yes"),Fact(headache="no"),Fact(sore_throat="yes"))
	def med29(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين + أبيبول"))
# رشح + التهاب حلق مع امراض مزمنة(ضغط,سكري)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="yes"),Fact(pressure="yes"),Fact(headache="no"),Fact(sore_throat="yes"))
	def med30(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي + أبيبول"))
# رشح + التهاب حلق مع امراض مزمنة(ضغط,ربو)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="no"),Fact(pressure="yes"),Fact(headache="no"),Fact(sore_throat="yes"))
	def med31(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين + أبيبول"))
# رشح + التهاب حلق مع امراض مزمنة(سكري)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="yes"),Fact(pressure="no"),Fact(headache="no"),Fact(sore_throat="yes"))
	def med32(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي + أبيبول"))
 # صداع بدون امراض مزمنة
	@Rule(Fact(action='pharmacy'),Fact(runnynose="no"),Fact(asthma="no"),Fact(Diabetes="no"),Fact(pressure="no"),Fact(headache="yes"),Fact(sore_throat="no"))
	def med33(self):
		self.declare(Fact(medicine="بنادول أزرق"))
 # التهاب حلق بدون امراض مزمنة
	@Rule(Fact(action='pharmacy'),Fact(runnynose="no"),Fact(asthma="no"),Fact(Diabetes="no"),Fact(pressure="no"),Fact(headache="no"),Fact(sore_throat="yes"))
	def med34(self):
		self.declare(Fact(medicine="أبيبول"))
# التهاب حلق + صداع               
	@Rule(Fact(action='pharmacy'),Fact(runnynose="no"),Fact(asthma="no"),Fact(Diabetes="no"),Fact(pressure="no"),Fact(headache="yes"),Fact(sore_throat="yes"))
	def med35(self):
		self.declare(Fact(medicine="بانادول أزرق + أبيبول"))
        
	@Rule(Fact(action='pharmacy'),Fact(runnynose=""),Fact(asthma=""),Fact(Diabetes=""),Fact(pressure=""),Fact(headache=""),Fact(sore_throat=""))
	def med36(self):
		self.declare(Fact(medicine="Your Medicine Not Exist at Pharmacy"))

	@Rule(Fact(action='pharmacy'),Fact(medicine=MATCH.medicine))
	def disease(self, medicine):
		print("")
		id_medicine = medicine
		print("")
		print("The Appropriate medicine for your case is :  %s\n" %(id_medicine))


engine = pharmacy()
while(1):
    engine.reset()  
    engine.run()  
    print("Would you like to diagnose some other symptoms?")
    if input() == "no":
        break;
# Out:
# Welcome!
# We are so happy to help you find the appropriate medicine for your case
# We provide arabic translation for symptoms&chronic diseases and provide medicine in arabic for easy use ...
# Warn! Use this system only if you are 12 years old or more
# Now, answer the following questions by 'yes' or 'no'
#
#
# Runny Nose 'رشح': yes
# Diabetes 'مرض السكري': no
# Pressure 'ضغط': no
# Asthma 'ربو': no
# Headache 'صداع': no
# sore throat 'التهاب في الحلق': no
#
#
# The Appropriate medicine for your case is :  بانادول اصفر
#
# Would you like to diagnose some other symptoms?
# no

# %% [markdown]
# # Pharmaceutical expert systems with GUI

# %%
# call libraries
from tkinter import *
from experta import *

#create inference engine
class pharmacy(KnowledgeEngine):
	@DefFacts()
	def _initial_action(self):
		gui_form0= Tk()
		gui_form0.title("Pharmaceutical expert system")
		gui_form0.geometry("1000x700") 
		gui_form0.resizable(False, False)
		#gui_form.config(bg="#FF5C8D")  
		# Add image file
		bg = PhotoImage(file = "1.png")

		# Show image using label
		label1 = Label( gui_form0, image = bg)
		label1.place(x = 0, y = 0)
        #,bg="white", fg="black",width="1000",height="15"
		#lb0 = Label(gui_form,text="\n\n\nWelcome to Our Pharmaceutical expert system  !\n\n Enter your Symptoms and we will suggest you the appropriate medicine for your case ... \n\n\n",font=3000)
		#lb0.pack()
		lb1 = Label(gui_form0,text="Pharmaceutical expert system",font=('Arial', 15),bg="#047E8B",fg="white",width="90",height="5")
		lb1.place(x = 1, y = 251)
		gui_form0.mainloop()
        
        
		gui_form= Tk()
		gui_form.title("Pharmaceutical expert system")
		gui_form.geometry("1000x700") 
		gui_form.resizable(False, False)
		#gui_form.config(bg="#FF5C8D")  
		# Add image file
		bg = PhotoImage(file = "1.png")
  
		# Show image using label
		label1 = Label( gui_form, image = bg)
		label1.place(x = 0, y = 0)
        #,bg="white", fg="black",width="1000",height="15"
		#lb0 = Label(gui_form,text="\n\n\nWelcome to Our Pharmaceutical expert system  !\n\n Enter your Symptoms and we will suggest you the appropriate medicine for your case ... \n\n\n",font=3000)
		#lb0.pack()
		lb1 = Label(gui_form,text="\n\n\nWelcome !\nWe are so happy to help you find the appropriate medicine for your case\nWe provide arabic translation for symptoms&chronic diseases and provide medicine in arabic for easy use ... \n Warn! Use this system only if you are 12 years old or more\nNow, answer the following questions by 'yes' or 'no'\n\n",font=('Arial', 15),bg="#047E8B",fg="white",width="90")
		lb1.place(x = 1, y = 200)
		gui_form.mainloop()
        
		gui_form1 = Tk() #user interface
		gui_form1.title("Pharmaceutical expert system")
		gui_form1.geometry("1000x709")
		gui_form1.resizable(False, False)
		#gui_form1.config(bg="#FF5C8D") 
		bg = PhotoImage(file = "1.png")
		# Show image using label
		label1 = Label( gui_form1, image = bg)
		label1.place(x = 0, y = 0)
###############################################################################
		lb1 = Label(gui_form1,text="Runny Nose 'رشح'",width="20",font=('Arial', 15),fg="#047E8B")
		en1 = Entry(gui_form1,font=('Arial', 15),fg="#047E8B")
		lb1.place(x = 50, y = 70)
		en1.place(x = 50, y = 100)
###############################################################################
		lb2 = Label(gui_form1,text="Asthma 'ربو'",font=('Arial', 15),width="20",fg="#047E8B")
		en2 = Entry(gui_form1,font=('Arial', 15),fg="#047E8B")
		lb2.place(x = 50, y = 150)
		en2.place(x = 50, y = 180)
###############################################################################
		lb3 = Label(gui_form1,text="Diabetes 'مرض السكري'",width="20",font=('Arial', 15),fg="#047E8B")
		en3 = Entry(gui_form1,font=('Arial', 15),fg="#047E8B")
		lb3.place(x = 50, y = 230)
		en3.place(x = 50, y = 260)
###############################################################################
		lb4 = Label(gui_form1,text="Pressure 'ضغط'",width="20",font=('Arial', 15),fg="#047E8B")
		en4 = Entry(gui_form1,font=('Arial', 15),fg="#047E8B")
		lb4.place(x = 50, y = 310)
		en4.place(x = 50, y = 340)
###############################################################################
		lb5 = Label(gui_form1,text="Headache 'صداع'",width="20",font=('Arial', 15),fg="#047E8B")
		en5 = Entry(gui_form1,font=('Arial', 15),fg="#047E8B")
		lb5.place(x = 50, y = 400)
		en5.place(x = 50, y = 430)
###############################################################################
		lb6 = Label(gui_form1,text="sore throat 'التهاب في الحلق'",width="20",font=('Arial', 15),fg="#047E8B")
		en6 = Entry(gui_form1,font=('Arial', 15),fg="#047E8B")
		lb6.place(x = 50, y = 480)
		en6.place(x = 50, y = 510)
##############################################################################
		lb7 = Label(gui_form1,text="\n--------------------\n Please follow previous rules  !\n --------------------\n Answer  by 'yes' or 'no' only .. \n--------------------\nTo show result click the button\nthen,press the 'x' of this window \n--------------------\n",width="30",font=('Arial', 15),bg="#047E8B",fg="white",height="30")
		lb7.place(x = 680, y = 1)
###############################################################################
            
		def get_values():
			self.declare(Fact(runnynose=en1.get()))
			self.declare(Fact(asthma=en2.get()))
			self.declare(Fact(Diabetes=en3.get()))
			self.declare(Fact(pressure=en4.get()))
			self.declare(Fact(headache=en5.get()))
			self.declare(Fact(sore_throat=en6.get()))
#############################################################################
		btn = Button(gui_form1,command=get_values,text=" Find Medicine ",bg="#047E8B",fg="white",font=('Arial', 13),height="2",width="20",bd = '10')
		btn.place(x = 50, y = 570)
            
		gui_form1.mainloop()
		yield Fact(action="pharmacy")
        
##################################################################################################
#knowlege base
#medicine according to disease

# رشح بدون امراض مزمنة
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="no"),Fact(pressure="no"),Fact(headache="no"),Fact(sore_throat="no"))
	def med0(self):
		self.declare(Fact(medicine="بانادول اصفر"))
# رشح مع امراض مزمنة(ربو)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="no"),Fact(pressure="no"),Fact(headache="no"),Fact(sore_throat="no"))
	def med1(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي"))
 # رشح مع امراض مزمنة(ربو,سكري)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="yes"),Fact(pressure="no"),Fact(headache="no"),Fact(sore_throat="no"))
	def med2(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي"))
# رشح مع امراض مزمنة(ربو,سكري,ضغط)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="yes"),Fact(pressure="yes"),Fact(headache="no"),Fact(sore_throat="no"))
	def med3(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين"))
# رشح مع امراض مزمنة(ربو,ضغط)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="no"),Fact(pressure="yes"),Fact(headache="no"),Fact(sore_throat="no"))
	def med4(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين"))
# رشح مع امراض مزمنة(ضغط)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="no"),Fact(pressure="yes"),Fact(headache="no"),Fact(sore_throat="no"))
	def med5(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين"))
# رشح مع امراض مزمنة(ضغط,سكري)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="no"),Fact(asthma="no"),Fact(Diabetes="no"),Fact(pressure="no"),Fact(headache="no"),Fact(sore_throat="no"))
	def med6(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي"))
# رشح مع امراض مزمنة(سكري)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="yes"),Fact(pressure="no"),Fact(headache="no"),Fact(sore_throat="no"))
	def med7(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي"))
#رشح + صداع 
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="no"),Fact(pressure="no"),Fact(headache="yes"),Fact(sore_throat="no"))
	def med8(self):
		self.declare(Fact(medicine="بانادول أصفر"))
# رشح + صداع مع امراض مزمنة(ربو)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="no"),Fact(pressure="no"),Fact(headache="yes"),Fact(sore_throat="no"))
	def med9(self):
		self.declare(Fact(medicine="بانادول أصفر"))
# رشح+ صداع مع امراض مزمنة(ربو,سكري)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="yes"),Fact(pressure="no"),Fact(headache="yes"),Fact(sore_throat="no"))
	def med10(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي"))
 # رشح + صداع مع امراض مزمنة(ربو,سكري,ضغط)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="yes"),Fact(pressure="yes"),Fact(headache="yes"),Fact(sore_throat="no"))
	def med11(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين"))
  # رشح + صداع مع امراض مزمنة(ربو,ضغط)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="no"),Fact(pressure="yes"),Fact(headache="yes"),Fact(sore_throat="no"))
	def med12(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين"))
  # رشح + صداع مع امراض مزمنة(ضغط)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="no"),Fact(pressure="yes"),Fact(headache="yes"),Fact(sore_throat="no"))
	def med13(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين" ))
 # رشح + صداع مع امراض مزمنة(ضغط,سكري)    
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="yes"),Fact(pressure="yes"),Fact(headache="yes"),Fact(sore_throat="no"))
	def med14(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي"))
   # رشح + صداع مع امراض مزمنة(سكري)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="yes"),Fact(pressure="no"),Fact(headache="yes"),Fact(sore_throat="no"))
	def med15(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي"))
  # رشح + صداع + التهاب حلق
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="no"),Fact(pressure="no"),Fact(headache="yes"),Fact(sore_throat="yes"))
	def med16(self):
		self.declare(Fact(medicine="بانادول اصفر + أبيبول"))
 # رشح + صداع + التهاب حلق مع امراض مزمنة(ربو)       
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="no"),Fact(pressure="no"),Fact(headache="yes"),Fact(sore_throat="yes"))
	def med17(self):
		self.declare(Fact(medicine="بنادول أصفر+أبيبول"))
 # رشح+ صداع + التهاب حلق مع امراض مزمنة(ربو,سكري)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="yes"),Fact(pressure="no"),Fact(headache="yes"),Fact(sore_throat="yes"))
	def med18(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي+أبيبول"))
 # رشح + صداع + التهاب حلق مع امراض مزمنة(ربو,سكري,ضغط)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="yes"),Fact(pressure="yes"),Fact(headache="yes"),Fact(sore_throat="yes"))
	def med19(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين+أبيبول"))
# رشح + صداع + التهاب حلق مع امراض مزمنة(ربو,ضغط)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="no"),Fact(pressure="yes"),Fact(headache="yes"),Fact(sore_throat="yes"))
	def med20(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين+أبيبول"))
# رشح + صداع + التهاب حلق مع امراض مزمنة(ضغط)          
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="no"),Fact(pressure="yes"),Fact(headache="yes"),Fact(sore_throat="yes"))
	def med21(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين+أبيبول"))
# رشح + صداع + التهاب حلق مع امراض مزمنة(ضغط,سكري)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="yes"),Fact(pressure="yes"),Fact(headache="yes"),Fact(sore_throat="yes"))
	def med22(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي+أبيبول"))
 # رشح + صداع + التهاب حلق مع امراض مزمنة(سكري)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="yes"),Fact(pressure="no"),Fact(headache="yes"),Fact(sore_throat="yes"))
	def med23(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي+أبيبول"))
# رشح + التهاب حلق
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="no"),Fact(pressure="no"),Fact(headache="no"),Fact(sore_throat="yes"))
	def med24(self):
		self.declare(Fact(medicine="كلاريناز + أبيبول"))
# رشح + التهاب حلق مع امراض مزمنة(ربو)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="no"),Fact(pressure="no"),Fact(headache="no"),Fact(sore_throat="yes"))
	def med25(self):
		self.declare(Fact(medicine="كلاريناز + أبيبول"))
  # رشح+ التهاب حلق مع امراض مزمنة(ربو,سكري)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="yes"),Fact(pressure="no"),Fact(headache="no"),Fact(sore_throat="yes"))
	def med26(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي + أبيبول"))
# رشح + التهاب حلق مع امراض مزمنة(ربو,سكري,ضغط)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="yes"),Fact(pressure="yes"),Fact(headache="no"),Fact(sore_throat="yes"))
	def med27(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين + أبيبول"))
  # رشح + التهاب حلق مع امراض مزمنة(ربو,ضغط)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="no"),Fact(pressure="yes"),Fact(headache="no"),Fact(sore_throat="yes"))
	def med28(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين + أبيبول "))
# رشح + التهاب حلق مع امراض مزمنة(ضغط)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="no"),Fact(pressure="yes"),Fact(headache="no"),Fact(sore_throat="yes"))
	def med29(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين + أبيبول"))
# رشح + التهاب حلق مع امراض مزمنة(ضغط,سكري)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="yes"),Fact(pressure="yes"),Fact(headache="no"),Fact(sore_throat="yes"))
	def med30(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي + أبيبول"))
# رشح + التهاب حلق مع امراض مزمنة(ضغط,ربو)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="yes"),Fact(Diabetes="no"),Fact(pressure="yes"),Fact(headache="no"),Fact(sore_throat="yes"))
	def med31(self):
		self.declare(Fact(medicine="بانادول أزرق + قطرة اوتريفين + أبيبول"))
# رشح + التهاب حلق مع امراض مزمنة(سكري)
	@Rule(Fact(action='pharmacy'),Fact(runnynose="yes"),Fact(asthma="no"),Fact(Diabetes="yes"),Fact(pressure="no"),Fact(headache="no"),Fact(sore_throat="yes"))
	def med32(self):
		self.declare(Fact(medicine="بانادول أزرق + فيتامين سي + أبيبول"))
 # صداع بدون امراض مزمنة
	@Rule(Fact(action='pharmacy'),Fact(runnynose="no"),Fact(asthma="no"),Fact(Diabetes="no"),Fact(pressure="no"),Fact(headache="yes"),Fact(sore_throat="no"))
	def med33(self):
		self.declare(Fact(medicine="بنادول أزرق"))
 # التهاب حلق بدون امراض مزمنة
	@Rule(Fact(action='pharmacy'),Fact(runnynose="no"),Fact(asthma="no"),Fact(Diabetes="no"),Fact(pressure="no"),Fact(headache="no"),Fact(sore_throat="yes"))
	def med34(self):
		self.declare(Fact(medicine="أبيبول"))
# التهاب حلق + صداع               
	@Rule(Fact(action='pharmacy'),Fact(runnynose="no"),Fact(asthma="no"),Fact(Diabetes="no"),Fact(pressure="no"),Fact(headache="yes"),Fact(sore_throat="yes"))
	def med35(self):
		self.declare(Fact(medicine="بانادول أزرق + أبيبول"))
#if no inputs
	@Rule(Fact(action='pharmacy'),Fact(runnynose=""),Fact(asthma=""),Fact(Diabetes=""),Fact(pressure=""),Fact(headache=""),Fact(sore_throat=""))
	def med36(self):
		self.declare(Fact(medicine="Your Medicine Not Exist at Pharmacy"))



	@Rule(Fact(action='pharmacy'),Fact(medicine=MATCH.medicine))
	def disease(self, medicine):
		print("")
		id_medicine = medicine
		gui_form2 = Tk()
		gui_form2.title("Pharmaceutical expert system answer")
		gui_form2.geometry("1000x700")
		gui_form2.resizable(False, False)
		#gui_form2.config(bg="#FF5C8D") 
		bg = PhotoImage(file = "1.png")
  
		# Show image using label
		label1 = Label( gui_form2, image = bg)
		label1.place(x = 0, y = 0)
		lb0 = Label(gui_form2,text="the appropriate medicine is ",font=('Arial', 17),bg="#047E8B", fg="white",width="120",height="5")
		lb0.pack()
		var = StringVar()
		var.set(id_medicine)
		lb1 = Label(gui_form2, textvariable = var,font=('Arial', 17),bg="white", fg="#047E8B",width="120",height="5")
		lb1.pack()
#		lb2 = Label(gui_form2, text="If you Would like to diagnose some other symptoms click Enter,Else Exit ",font="150",bg="white", fg="#047E8B",width="1000",height="5")
#		lb2.pack()
        
#		btn20 = Button(gui_form2,text=" Enter ",bg="#047E8B",fg="white",font=('Arial', 15),height="2",width="20",bd = '10')
#		btn20.pack() ##################هوصلها بلينك الفورم
		gui_form2.mainloop()

#run class
engine = pharmacy()
while(1):
    engine.reset()  # Prepare the engine for the execution.
    engine.run()  # Run it!
    print("Would you like to diagnose some other symptoms?")
    if input() == "no":
        break;
# Out:
# WARNING:experta.watchers.ENGINE:Declaring fact before reset()
# Would you like to diagnose some other symptoms?
